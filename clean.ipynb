# %%
import pandas as pd

# %%
season23 = pd.read_csv("2023_season.csv")

# %%
season23.tail()
# Out:
#      Unnamed: 0        Date   Time            Comp         Round  Day Venue  \
# 393          18  2022-12-26  15:00  Premier League  Matchweek 17  Mon  Home
# 394          19  2022-12-31  15:00  Premier League  Matchweek 18  Sat  Away
# 395          20  2023-01-04  19:30  Premier League  Matchweek 19  Wed  Home
# 396          23  2023-01-14  15:00  Premier League  Matchweek 20  Sat  Away
# 397          24  2023-01-21  15:00  Premier League  Matchweek 21  Sat  Home
#
#     Result   GF   GA  ...  Match Report  Notes    Sh  SoT  Dist   FK PK PKatt  \
# 393      L  1.0  3.0  ...  Match Report    NaN  13.0  3.0  16.1  1.0  0     1
# 394      L  1.0  2.0  ...  Match Report    NaN   9.0  3.0  24.5  1.0  0     0
# 395      L  0.0  1.0  ...  Match Report    NaN   8.0  0.0  14.5  1.0  0     0
# 396      W  2.0  1.0  ...  Match Report    NaN  13.0  5.0  20.7  2.0  0     0
# 397      L  0.0  1.0  ...  Match Report    NaN   8.0  5.0  15.8  0.0  0     0
#
#     Season               team
# ...

# %%
season23 = season23.drop("Unnamed: 0", axis = 1)
season23.columns
# Out:
# Index(['Date', 'Time', 'Comp', 'Round', 'Day', 'Venue', 'Result', 'GF', 'GA',
#        'Opponent', 'xG', 'xGA', 'Poss', 'Attendance', 'Captain', 'Formation',
#        'Referee', 'Match Report', 'Notes', 'Sh', 'SoT', 'Dist', 'FK', 'PK',
#        'PKatt', 'Season', 'team'],
#       dtype='object')

# %%
season22 = pd.read_csv("2021_2022_season.csv")

# %%
season22.head()
# Out:
#    Unnamed: 0        Date   Time            Comp        Round  Day Venue  \
# 0           1  2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away
# 1           2  2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home
# 2           3  2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home
# 3           4  2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away
# 4           6  2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home
#
#   Result  GF  GA  ...  Match Report  Notes    Sh   SoT  Dist   FK   PK PKatt  \
# 0      L   0   1  ...  Match Report    NaN  18.0   4.0  17.3  1.0  0.0   0.0
# 1      W   5   0  ...  Match Report    NaN  16.0   4.0  18.5  1.0  0.0   0.0
# 2      W   5   0  ...  Match Report    NaN  25.0  10.0  14.8  0.0  0.0   0.0
# 3      W   1   0  ...  Match Report    NaN  25.0   8.0  14.3  0.0  0.0   0.0
# 4      D   0   0  ...  Match Report    NaN  16.0   1.0  16.4  1.0  0.0   0.0
#
#   Season                   team
# ...

# %%
season = [2022 for i in range(len(season22))]
season22 = season22.drop("Season", axis = 1)
season22['season'] = season

# %%
season22 = season22.drop("Unnamed: 0", axis = 1)

# %%
season22.columns
# Out:
# Index(['Date', 'Time', 'Comp', 'Round', 'Day', 'Venue', 'Result', 'GF', 'GA',
#        'Opponent', 'xG', 'xGA', 'Poss', 'Attendance', 'Captain', 'Formation',
#        'Referee', 'Match Report', 'Notes', 'Sh', 'SoT', 'Dist', 'FK', 'PK',
#        'PKatt', 'team', 'season'],
#       dtype='object')

# %%
season22.head()
# Out:
#          Date   Time            Comp        Round  Day Venue Result  GF  GA  \
# 0  2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L   0   1
# 1  2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W   5   0
# 2  2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W   5   0
# 3  2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W   1   0
# 4  2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D   0   0
#
#          Opponent  ...  Match Report  Notes    Sh   SoT  Dist   FK   PK PKatt  \
# 0       Tottenham  ...  Match Report    NaN  18.0   4.0  17.3  1.0  0.0   0.0
# 1    Norwich City  ...  Match Report    NaN  16.0   4.0  18.5  1.0  0.0   0.0
# 2         Arsenal  ...  Match Report    NaN  25.0  10.0  14.8  0.0  0.0   0.0
# 3  Leicester City  ...  Match Report    NaN  25.0   8.0  14.3  0.0  0.0   0.0
# 4     Southampton  ...  Match Report    NaN  16.0   1.0  16.4  1.0  0.0   0.0
#
#                     team  season
# ...

# %%
season21 = pd.read_csv("2020_2021_season.csv")

# %%
season21 = season21.drop("Unnamed: 0", axis = 1)
season21.columns
# Out:
# Index(['Date', 'Time', 'Comp', 'Round', 'Day', 'Venue', 'Result', 'GF', 'GA',
#        'Opponent', 'xG', 'xGA', 'Poss', 'Attendance', 'Captain', 'Formation',
#        'Referee', 'Match Report', 'Notes', 'Sh', 'SoT', 'Dist', 'FK', 'PK',
#        'PKatt', 'Season', 'team'],
#       dtype='object')

# %%
season21.tail()
# Out:
#            Date   Time            Comp         Round  Day Venue Result  GF  \
# 755  2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L   0
# 756  2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L   0
# 757  2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W   1
# 758  2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L   0
# 759  2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W   1
#
#      GA        Opponent  ...  Match Report  Notes    Sh  SoT  Dist   FK   PK  \
# 755   4       Tottenham  ...  Match Report    NaN   8.0  1.0  18.2  0.0  0.0
# 756   2  Crystal Palace  ...  Match Report    NaN   7.0  0.0  13.4  1.0  0.0
# 757   0         Everton  ...  Match Report    NaN  10.0  3.0  18.5  0.0  0.0
# 758   1   Newcastle Utd  ...  Match Report    NaN  11.0  1.0  18.3  1.0  0.0
# 759   0         Burnley  ...  Match Report    NaN  12.0  3.0  17.4  0.0  0.0
#
#     PKatt  Season                    team
# ...

# %%
season = [2021 for i in range(len(season21))]
season21 = season21.drop("Season", axis = 1)
season21['season'] = season
season21.head()
# Out:
#          Date   Time            Comp        Round  Day Venue Result  GF  GA  \
# 0  2020-09-21  20:15  Premier League  Matchweek 2  Mon  Away      W   3   1
# 1  2020-09-27  16:30  Premier League  Matchweek 3  Sun  Home      L   2   5
# 2  2020-10-03  17:30  Premier League  Matchweek 4  Sat  Away      D   1   1
# 3  2020-10-17  17:30  Premier League  Matchweek 5  Sat  Home      W   1   0
# 4  2020-10-24  12:30  Premier League  Matchweek 6  Sat  Away      D   1   1
#
#          Opponent  ...  Match Report  Notes    Sh  SoT  Dist   FK   PK PKatt  \
# 0          Wolves  ...  Match Report    NaN  13.0  8.0  21.1  2.0  1.0   1.0
# 1  Leicester City  ...  Match Report    NaN  16.0  5.0  19.8  1.0  0.0   0.0
# 2    Leeds United  ...  Match Report    NaN  23.0  1.0  18.2  1.0  0.0   0.0
# 3         Arsenal  ...  Match Report    NaN  13.0  5.0  17.7  0.0  0.0   0.0
# 4        West Ham  ...  Match Report    NaN  14.0  7.0  20.9  1.0  0.0   0.0
#
#                     team  season
# ...

# %%
season22.columns = [c.lower() for c in season22.columns]
season22.head()
# Out:
#          date   time            comp        round  day venue result  gf  ga  \
# 0  2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L   0   1
# 1  2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W   5   0
# 2  2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W   5   0
# 3  2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W   1   0
# 4  2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D   0   0
#
#          opponent  ...  match report  notes    sh   sot  dist   fk   pk pkatt  \
# 0       Tottenham  ...  Match Report    NaN  18.0   4.0  17.3  1.0  0.0   0.0
# 1    Norwich City  ...  Match Report    NaN  16.0   4.0  18.5  1.0  0.0   0.0
# 2         Arsenal  ...  Match Report    NaN  25.0  10.0  14.8  0.0  0.0   0.0
# 3  Leicester City  ...  Match Report    NaN  25.0   8.0  14.3  0.0  0.0   0.0
# 4     Southampton  ...  Match Report    NaN  16.0   1.0  16.4  1.0  0.0   0.0
#
#                     team  season
# ...

# %%
season23.columns = [c.lower() for c in season23.columns]
season23.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 0  2022-08-05  20:00  Premier League  Matchweek 1  Fri  Away      W  2.0  0.0
# 1  2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W  4.0  2.0
# 2  2022-08-20  17:30  Premier League  Matchweek 3  Sat  Away      W  3.0  0.0
# 3  2022-08-27  17:30  Premier League  Matchweek 4  Sat  Home      W  2.0  1.0
# 4  2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W  2.0  1.0
#
#          opponent  ...  match report  notes    sh  sot  dist   fk pk pkatt  \
# 0  Crystal Palace  ...  Match Report    NaN  10.0  2.0  14.6  1.0  0     0
# 1  Leicester City  ...  Match Report    NaN  19.0  7.0  13.0  0.0  0     0
# 2     Bournemouth  ...  Match Report    NaN  14.0  6.0  14.8  0.0  0     0
# 3          Fulham  ...  Match Report    NaN  22.0  8.0  15.5  1.0  0     0
# 4     Aston Villa  ...  Match Report    NaN  22.0  8.0  16.3  1.0  0     0
#
#    season           team
# ...

# %%
season21.columns = [c.lower() for c in season22.columns]
season21.head()
# Out:
#          date   time            comp        round  day venue result  gf  ga  \
# 0  2020-09-21  20:15  Premier League  Matchweek 2  Mon  Away      W   3   1
# 1  2020-09-27  16:30  Premier League  Matchweek 3  Sun  Home      L   2   5
# 2  2020-10-03  17:30  Premier League  Matchweek 4  Sat  Away      D   1   1
# 3  2020-10-17  17:30  Premier League  Matchweek 5  Sat  Home      W   1   0
# 4  2020-10-24  12:30  Premier League  Matchweek 6  Sat  Away      D   1   1
#
#          opponent  ...  match report  notes    sh  sot  dist   fk   pk pkatt  \
# 0          Wolves  ...  Match Report    NaN  13.0  8.0  21.1  2.0  1.0   1.0
# 1  Leicester City  ...  Match Report    NaN  16.0  5.0  19.8  1.0  0.0   0.0
# 2    Leeds United  ...  Match Report    NaN  23.0  1.0  18.2  1.0  0.0   0.0
# 3         Arsenal  ...  Match Report    NaN  13.0  5.0  17.7  0.0  0.0   0.0
# 4        West Ham  ...  Match Report    NaN  14.0  7.0  20.9  1.0  0.0   0.0
#
#                     team  season
# ...

# %%
pdList = [season23, season22, season21]

# %%
match_df = pd.concat(pdList)

# %%
match_df.to_csv("total.csv", index=False)
